# %%
# -*- coding: utf-8 -*-
import re
import sys

from activity_browser import run_activity_browser

if __name__ == '__main__':
    sys.argv[0] = re.sub(r'(-script\.pyw?|\.exe)?$', '', sys.argv[0])
    sys.exit(run_activity_browser())
# Out:
# 12:01:26 | INFO | Activity Browser version: 2.11.2
# 12:01:27 | INFO | Brightway2 data directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3
# 12:01:27 | INFO | Brightway2 current project: default
# 12:01:27 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\default.c21f969b5f03d33d43e04f8f136e7682
# 12:01:27 | INFO | Loaded tab 'ab_plugin_contribution_analysis'
# 12:01:33 | INFO | Brightway2 current project: AEMEL Schropp MS v1 (Eleonora)
# 12:01:33 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\AEMEL-Schropp-MS-v1-Eleonora.77a1a4c3794bb8320e7e949391242c89
# 12:01:33 | INFO | Loaded tab 'ab_plugin_contribution_analysis'
# 12:01:33 | INFO | Loaded tab 'ab_plugin_IF_analysis'
# 12:01:36 | INFO | Created LCA object
# Selected Activity: AEM stack, plant with 1000 kg H2/d
# , AEM stack, plant with 1000 kg H2/d
# , GLO (key: ('AEMEL_schropp', 'b41bfd4f33a94e09aa95ac43db2716bf'))
# Sélection: Database : AEMEL_schropp, Activity : b41bfd4f33a94e09aa95ac43db2716bf , Method_ef : ('EF v3.0', 'energy resources: non-renewable', 'abiotic depletion potential (ADP): fossil fuels'), Method_if : Criticality method
# 12:01:38 | INFO | Created LCA object
# C:\Users\mael.mouhoub\Documents\2-Recherche\5-Git_repositories\ab-plugin-IF_analysis\ab_plugin_IF_analysis\widgets\IFC_widget.py:153: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_ef_if = pd.concat([result_ef, result_if], axis=0)
#   Type                                      Flow     Inventory             CF  \
# 0   EF                   Gas, natural, in ground  1.069993e+04      34.500000
# 1   EF                     Oil, crude, in ground  8.595559e+03      42.299999
# 2   EF        Coal, hard, unspecified, in ground  1.361347e+04      18.010000
# 3   EF                        Uranium, in ground  2.964255e-01  560000.000000
# 4   EF                    Coal, brown, in ground  5.636793e+03       9.410000
# 5   EF  Gas, mine, off-gas, process, coal mining  1.131714e+02      35.869999
# 6   EF                           Peat, in ground  6.661715e+01       9.760000
# 7   EF                            1,4-Butanediol  4.586123e-07       0.000000
# 8   EF                                1-Pentanol  3.681006e-08       0.000000
# 9   EF                                 1-Pentene  7.692175e-07       0.000000
#
#   Activity      LCA Score
# 0           369147.727703
# 1           363592.145833
# 2           245178.584143
# 3           165998.253845
# 4            53042.223487
# 5             4059.459538
# 6              650.183362
# 7                0.000000
# 8                0.000000
# 9                0.000000
# 12:01:49 | INFO | Created LCA object
# Selected Activity: Module, Module, GLO (key: ('Modular structure', 'Module'))
# Sélection: Database : Modular structure, Activity : Module , Method_ef : ('EF v3.0', 'energy resources: non-renewable', 'abiotic depletion potential (ADP): fossil fuels'), Method_if : Criticality method
# 12:01:51 | INFO | Created LCA object
#   Type                                       Flow     Inventory  \
# 0   EF                    Gas, natural, in ground  10679.813168
# 1   EF                      Oil, crude, in ground   8573.455150
# 2   EF         Coal, hard, unspecified, in ground  13603.066009
# 3   EF                         Uranium, in ground      0.295851
# 4   IF  Bipolar plate, Stainless steel hot rolled   1837.737036
# 5   EF                     Coal, brown, in ground   5625.941806
# 6   IF                End plates, Stainless steel   2935.055664
# 7   EF   Gas, mine, off-gas, process, coal mining    113.086033
# 8   EF                            Peat, in ground     66.462244
# 9   IF                Catalyst, Nickel Molybdenum      5.547579
#
#               CF                                   Activity      LCA Score
# 0      34.500000                                             368453.554281
# 1      42.299999                                             362657.146309
# 2      18.010000                                             244991.221942
# 3  560000.000000                                             165676.771050
# 4      50.000000  Bipolar plate, Stainless steel hot rolled   91886.851788
# 5       9.410000                                              52940.111533
# 6      10.000000                End plates, Stainless steel   29350.556641
# 7      35.869999                                               4056.395871
# 8       9.760000                                                648.671516
# 9      20.000000                Catalyst, Nickel Molybdenum     110.951573
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\IPython\core\interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
