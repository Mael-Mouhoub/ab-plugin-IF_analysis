# %%
# -*- coding: utf-8 -*-
import re
import sys

from activity_browser import run_activity_browser

if __name__ == '__main__':
    sys.argv[0] = re.sub(r'(-script\.pyw?|\.exe)?$', '', sys.argv[0])
    sys.exit(run_activity_browser())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import re
#       3 import sys
# ----> 5 from activity_browser import run_activity_browser
#       7 if __name__ == '__main__':
#       8     sys.argv[0] = re.sub(r'(-script\.pyw?|\.exe)?$', '', sys.argv[0])
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\__init__.py:12
#      10 from .settings import ab_settings, project_settings
#      11 from .info import __version__ as version
# ---> 12 from .layouts.main import MainWindow
#      13 from .plugin import Plugin
#      14 from .controllers import *
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\layouts\__init__.py:2
#       1 # -*- coding: utf-8 -*-
# ----> 2 from .main import MainWindow
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\layouts\main.py:8
#       6 from ..signals import signals
#       7 from ..ui.icons import qicons
# ----> 8 from ..ui.menu_bar import MenuBar
#       9 from ..ui.statusbar import Statusbar
#      10 from ..ui.style import header
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\ui\menu_bar.py:7
#       4 from PySide2 import QtGui, QtWidgets
#       5 from PySide2.QtCore import QSize, QUrl, Slot
# ----> 7 from activity_browser import actions, signals, application, info
#       8 from activity_browser.mod import bw2data as bd
#      10 from .icons import qicons
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\actions\__init__.py:59
#      57 from .default_install import DefaultInstall
#      58 from .biosphere_update import BiosphereUpdate
# ---> 59 from .plugin_wizard_open import PluginWizardOpen
#      60 from .settings_wizard_open import SettingsWizardOpen
#      61 from .migrations_install import MigrationsInstall
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\actions\plugin_wizard_open.py:4
#       2 from activity_browser.actions.base import ABAction, exception_dialogs
#       3 from activity_browser.ui.icons import qicons
# ----> 4 from activity_browser.ui.wizards.plugins_manager_wizard import \
#       5     PluginsManagerWizard
#       8 class PluginWizardOpen(ABAction):
#       9     """ABAction to open the PluginWizard"""
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\ui\wizards\plugins_manager_wizard.py:7
#       5 from ...signals import signals
#       6 from ...ui.style import header
# ----> 7 from ...ui.tables import PluginsTable
#      10 class PluginsManagerWizard(QtWidgets.QWizard):
#      11     def __init__(self, key: tuple, parent=None):
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\ui\tables\__init__.py:24
#      16 from .LCA_setup import CSActivityTable, CSList, CSMethodsTable, ScenarioImportTable
#      17 from .parameters import (
#      18     ActivityParameterTable,
#      19     BaseParameterTable,
#    (...)     22     ProjectParameterTable,
#      23 )
# ---> 24 from .plugins import PluginsTable
#      25 from .projects import ProjectListWidget
#      26 from .scenarios import ScenarioTable
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\ui\tables\plugins.py:8
#       6 from ...signals import signals
#       7 from .delegates import CheckboxDelegate
# ----> 8 from .models.plugins import PluginsModel
#       9 from .views import ABDataFrameView
#      12 class PluginsTable(ABDataFrameView):
#
# File ~\AppData\Local\anaconda3\envs\ab\Lib\site-packages\shiboken2\files.dir\shibokensupport\feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1150, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:705, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in _LoaderBasics.exec_module(self, module)
#     934 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap_external>:1033, in SourceLoader.get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1130, in FileLoader.get_data(self, path)
#    1127 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:
