# %%
# -*- coding: utf-8 -*-
import re
import sys

from activity_browser import run_activity_browser

if __name__ == '__main__':
    sys.argv[0] = re.sub(r'(-script\.pyw?|\.exe)?$', '', sys.argv[0])
    sys.exit(run_activity_browser())
# Out:
# 14:50:02 | INFO | Activity Browser version: 2.11.2
# 14:50:02 | INFO | Activity Browser version: 2.11.2
# 14:50:07 | INFO | Brightway2 data directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3
# 14:50:07 | INFO | Brightway2 data directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3
# 14:50:07 | INFO | Brightway2 current project: default
# 14:50:07 | INFO | Brightway2 current project: default
# 14:50:07 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\default.c21f969b5f03d33d43e04f8f136e7682
# 14:50:07 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\default.c21f969b5f03d33d43e04f8f136e7682
# 14:50:07 | INFO | Loaded tab 'ab_plugin_contribution_analysis'
# 14:50:07 | INFO | Loaded tab 'ab_plugin_contribution_analysis'
# 14:50:13 | INFO | Brightway2 current project: H2Plugin_3.12_import
# 14:50:13 | INFO | Brightway2 current project: H2Plugin_3.12_import
# 14:50:13 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\H2Plugin_312_import.6865efd982ad913303e818f145e170c6
# 14:50:13 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\H2Plugin_312_import.6865efd982ad913303e818f145e170c6
# 14:50:18 | INFO | Loaded tab 'ab_plugin_IF_analysis'
# 14:50:18 | INFO | Loaded tab 'ab_plugin_IF_analysis'
# 14:50:28 | INFO | Created LCA object
# 14:50:28 | INFO | Created LCA object
# Selected Activity: Bipolar Plate, Bipolar Plate, GLO (key: ('AEMEL schropp', 'Bipolar Plate'))
# Sélection: Database : AEMEL schropp, Activity : Bipolar Plate , Method_if : SH2E
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\IPython\core\interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
1+1
# Out:
# 2

# %%
import brightway2 as bw
from  brightway2 import *
import ast
import pandas as pd
from lca_ef_if import lca_ef,lca_if

bw.projects.set_current("AEMEL Schropp MS v1 (Eleonora)")

# %%
excel_path = r"C:\Users\mael.mouhoub\Documents\2-Recherche\5-Git_repositories\ab-plugin-IF_analysis\ab_plugin_IF_analysis\utils\method_input.xlsx"        
if_panda = pd.read_excel(excel_path)
list_methods_if = list(if_panda["method"].unique())       
method_if_name = "SH2E"
method_if = if_panda[if_panda["method"] == method_if_name]
key = ('AEMEL_schropp', 'b41bfd4f33a94e09aa95ac43db2716bf')

# %%
method_if
# Out:
#                             product  \
# 6    aluminium oxide, metallurgical
# 7    aluminium oxide, metallurgical
# 8    aluminium oxide, metallurgical
# 9    aluminium oxide, metallurgical
# 10   aluminium oxide, metallurgical
# ..                              ...
# 114             strontium carbonate
# 115                   terbium oxide
# 116        terbium-dysprosium oxide
# 117                 titanium sponge
# 118                   yttrium oxide
#
#                                       activity  \
# 6    market for aluminium oxide, metallurgical
# 7    market for aluminium oxide, metallurgical
# 8    market for aluminium oxide, metallurgical
# 9    market for aluminium oxide, metallurgical
# 10   market for aluminium oxide, metallurgical
# ..                                         ...
# 114             market for strontium carbonate
# 115                   market for terbium oxide
# 116        market for terbium-dysprosium oxide
# 117                 market for titanium sponge
# 118                   market for yttrium oxide
#
#                                   location      unit  category  \
# 6    IAI Area, Asia, without China and GCC  kilogram       NaN
# 7                                       CN  kilogram       NaN
# 8                                      RoW  kilogram       NaN
# 9     IAI Area, Western and Central Europe  kilogram       NaN
# 10                                      CA  kilogram       NaN
# ..                                     ...       ...       ...
# 114                                    GLO  kilogram       NaN
# 115                                    GLO  kilogram       NaN
# 116                                    GLO  kilogram       NaN
# 117                                    GLO  kilogram       NaN
# 118                                    GLO  kilogram       NaN
#
#                                                    key            cf method  \
# 6    ('ecoinvent-3.12-cutoff', '8aacfd62fca4bfa1ad9...  6.775040e-08   SH2E
# 7    ('ecoinvent-3.12-cutoff', '642a9155ba85f790521...  6.775040e-08   SH2E
# 8    ('ecoinvent-3.12-cutoff', 'd4540c46f683bd26a83...  6.775040e-08   SH2E
# 9    ('ecoinvent-3.12-cutoff', 'd6aaedba43d5049debb...  6.775040e-08   SH2E
# 10   ('ecoinvent-3.12-cutoff', '60e94100a96f16fb5c6...  6.775040e-08   SH2E
# ..                                                 ...           ...    ...
# 114  ('ecoinvent-3.12-cutoff', '00badc540c4a9113169...  2.148470e-05   SH2E
# 115  ('ecoinvent-3.12-cutoff', 'a36b6372f1864c77a68...  7.396740e-01   SH2E
# 116  ('ecoinvent-3.12-cutoff', 'f0f540ef65bb1008cf4...  0.000000e+00   SH2E
# 117  ('ecoinvent-3.12-cutoff', 'e684e30bc72b6ca915d...  4.455000e-03   SH2E
# 118  ('ecoinvent-3.12-cutoff', '3654e688e05b6155f8a...  4.887270e-01   SH2E
#
#            crm
# 6    aluminium
# 7    aluminium
# 8    aluminium
# 9    aluminium
# 10   aluminium
# ..         ...
# 114  strontium
# 115    terbium
# 116    terbium
# 117   titanium
# 118    yttrium
#
# [113 rows x 9 columns]

# %%
random_method = list(methods)[1]
method = Method(random_method)#random method we only need supply chain
lca = LCA({key: 1}, random_method)
lca.lci()
lca.lcia()
lca_score = lca.score
activity_dict = lca.activity_dict
supply_array = lca.supply_array
print(lca_score)
results_df = pd.DataFrame(columns=["Type",'Flow',"Inventory","CF", 'Activity', 'LCA Score'])
for index,if_flows in method_if.iterrows():
    key_flow = ast.literal_eval(if_flows["key"])
    results_df.loc[len(results_df)] = {
    "Type" : "IF",
    'Flow': if_flows["product"],
    'Activity': Database(key_flow[0]).get(key_flow[1])["name"],
    "Inventory":supply_array[activity_dict[key_flow]],
    "CF":if_flows["cf"],
    'LCA Score': if_flows["cf"] * supply_array[activity_dict[key_flow]],
    }
    print(key_flow)
    
# Extraire les noms des colonnes et les données
# Out:
# 09:28:08 | INFO | Created LCA object
# 0.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\peewee.py:7525, in BaseModelSelect.get(self, database)
#    7524 try:
# -> 7525     return clone.execute(database)[0]
#    7526 except IndexError:
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\peewee.py:4746, in CursorWrapper.__getitem__(self, item)
#    4745     self.fill_cache(item if item > 0 else 0)
# -> 4746     return self.row_cache[item]
#    4747 else:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ActivityDatasetDoesNotExist               Traceback (most recent call last)
# Cell In[7], line 16
#      12     key_flow = ast.literal_eval(if_flows["key"])
#      13     results_df.loc[len(results_df)] = {
#      14     "Type" : "IF",
#      15     'Flow': if_flows["product"],
# ---> 16     'Activity': Database(key_flow[0]).get(key_flow[1])["name"],
#      17     "Inventory":supply_array[activity_dict[key_flow]],
#      18     "CF":if_flows["cf"],
#      19     'LCA Score': if_flows["cf"] * supply_array[activity_dict[key_flow]],
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\activity_browser\mod\bw2data\backends\base.py:74, in SQLiteBackend.get(self, code)
#      73 def get(self, code) -> Activity:
# ---> 74     return patched[SQLiteBackend]["get"](self, code)
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\bw2data\backends\peewee\database.py:133, in SQLiteBackend.get(self, code)
#     130 def get(self, code):
#     131     return Activity(
#     132         self._get_queryset(filters=False).where(
# --> 133             ActivityDataset.code == code).get()
#     134     )
#
# File c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\peewee.py:7528, in BaseModelSelect.get(self, database)
#    7526 except IndexError:
#    7527     sql, params = clone.sql()
# -> 7528     raise self.model.DoesNotExist('%s instance matching query does '
#    7529                                   'not exist:\nSQL: %s\nParams: %s' %
#    7530                                   (clone.model, sql, params))
#
# ActivityDatasetDoesNotExist: <Model: ActivityDataset> instance matching query does not exist:
# SQL: SELECT "t1"."id", "t1"."data", "t1"."code", "t1"."database", "t1"."location", "t1"."name", "t1"."product", "t1"."type" FROM "activitydataset" AS "t1" WHERE (("t1"."database" = ?) AND ("t1"."code" = ?)) ORDER BY Random() LIMIT ? OFFSET ?
# Params: ['ecoinvent-3.12-cutoff', '8aacfd62fca4bfa1ad986b651deb8f9d', 1, 0]

# %%
# -*- coding: utf-8 -*-
import re
import sys

from activity_browser import run_activity_browser

if __name__ == '__main__':
    sys.argv[0] = re.sub(r'(-script\.pyw?|\.exe)?$', '', sys.argv[0])
    sys.exit(run_activity_browser())
# Out:
# 10:37:10 | INFO | Activity Browser version: 2.11.2
# 10:37:10 | INFO | Activity Browser version: 2.11.2
# 10:37:14 | INFO | Brightway2 data directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3
# 10:37:14 | INFO | Brightway2 data directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3
# 10:37:14 | INFO | Brightway2 current project: default
# 10:37:14 | INFO | Brightway2 current project: default
# 10:37:14 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\default.c21f969b5f03d33d43e04f8f136e7682
# 10:37:14 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\default.c21f969b5f03d33d43e04f8f136e7682
# 10:37:14 | INFO | Loaded tab 'ab_plugin_contribution_analysis'
# 10:37:14 | INFO | Loaded tab 'ab_plugin_contribution_analysis'
# 10:37:23 | INFO | Brightway2 current project: AEMEL Schropp MS v1 (Eleonora)
# 10:37:23 | INFO | Brightway2 current project: AEMEL Schropp MS v1 (Eleonora)
# 10:37:23 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\AEMEL-Schropp-MS-v1-Eleonora.77a1a4c3794bb8320e7e949391242c89
# 10:37:23 | INFO | Project settings directory: C:\Users\mael.mouhoub\AppData\Local\pylca\Brightway3\AEMEL-Schropp-MS-v1-Eleonora.77a1a4c3794bb8320e7e949391242c89
# 10:37:23 | INFO | Loaded tab 'ab_plugin_contribution_analysis'
# 10:37:23 | INFO | Loaded tab 'ab_plugin_contribution_analysis'
# 10:37:32 | INFO | Loaded tab 'ab_plugin_IF_analysis'
# 10:37:32 | INFO | Loaded tab 'ab_plugin_IF_analysis'
# Selected Activity: AEM stack, plant with 1000 kg H2/d
# , AEM stack, plant with 1000 kg H2/d
# , GLO (key: ('AEMEL_schropp', 'b41bfd4f33a94e09aa95ac43db2716bf'))
# Sélection: Database : AEMEL_schropp, Activity : b41bfd4f33a94e09aa95ac43db2716bf , Method_ef : ('EF v3.0', 'energy resources: non-renewable', 'abiotic depletion potential (ADP): fossil fuels'), Method_if : Criticality method
# 10:38:14 | INFO | Created LCA object
# 10:38:14 | INFO | Created LCA object
# 10:38:21 | INFO | Created LCA object
# 10:38:21 | INFO | Created LCA object
# 10:42:54 | ERROR | AttributeError: 'list' object has no attribute 'iterrows'
# Traceback (most recent call last):
#   File "C:\Users\mael.mouhoub\Documents\2-Recherche\5-Git_repositories\ab-plugin-IF_analysis\ab_plugin_IF_analysis\widgets\IFC_widget.py", line 160, in calcultate_if_ef
#     result_if = lca_if(activity_key,method_if)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\mael.mouhoub\Documents\2-Recherche\5-Git_repositories\ab-plugin-IF_analysis\ab_plugin_IF_analysis\utils\lca_ef_if.py", line 21, in lca_if
#     for index,if_flows in method_flows.iterrows():
#                           ^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'iterrows'
# 10:42:54 | ERROR | AttributeError: 'list' object has no attribute 'iterrows'
# Traceback (most recent call last):
#   File "C:\Users\mael.mouhoub\Documents\2-Recherche\5-Git_repositories\ab-plugin-IF_analysis\ab_plugin_IF_analysis\widgets\IFC_widget.py", line 160, in calcultate_if_ef
#     result_if = lca_if(activity_key,method_if)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\mael.mouhoub\Documents\2-Recherche\5-Git_repositories\ab-plugin-IF_analysis\ab_plugin_IF_analysis\utils\lca_ef_if.py", line 21, in lca_if
#     for index,if_flows in method_flows.iterrows():
#                           ^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'iterrows'
# An exception has occurred, use %tb to see the full traceback.
#
#
#
# SystemExit: 0
# c:\Users\mael.mouhoub\AppData\Local\anaconda3\envs\ab\Lib\site-packages\IPython\core\interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
